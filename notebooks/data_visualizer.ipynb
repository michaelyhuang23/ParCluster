# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('../dataset/reallife/PAMAP2.dat') as f:
    lines = f.readlines()
    lines = [[float(num) for num in line.split()] for line in lines]
    print(lines[0])
# Out:
# [0.247929, 0.785903, 0.0620537, 0.56306]

# %%
lines = np.array(lines)
sns.scatterplot(x=lines[:,0], y=lines[:,3])
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(x=lines[:,0], y=lines[:,1])
# Out:
# <AxesSubplot:>
